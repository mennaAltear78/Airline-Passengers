# %%
# %pip install numpy pandas matplotlib statsmodels scikit-learn
# Out:
# Requirement already satisfied: numpy in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (2.2.6)
# Requirement already satisfied: pandas in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (3.10.9)
# Collecting statsmodels
#   Downloading statsmodels-0.14.6-cp310-cp310-win_amd64.whl (9.6 MB)
# Requirement already satisfied: scikit-learn in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (1.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: pytz>=2020.1 in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (from pandas) (2026.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (from statsmodels) (1.15.3)
# Collecting patsy>=0.5.6
#   Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: joblib>=1.2.0 in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in e:\new folder\menna ahmed khamis\after iti\ai\jupyter_lab\projects\5-credit_card_fraud_detection\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-1.0.2 statsmodels-0.14.6
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 26.2.1 is available.
# You should consider upgrading via the 'e:\New folder\menna ahmed khamis\after iti\Ai\Jupyter_lab\projects\5-Credit_card_fraud_detection\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# importing the required dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    root_mean_squared_error
)

# %%
# load data
df = pd.read_csv("airline-passengers.csv")
print("Dataset shape:", df.shape)
display(df.head(10))
display(df.tail(10))
# Out:
# Dataset shape: (144, 2)
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121
# 5  1949-06         135
# 6  1949-07         148
# 7  1949-08         148
# 8  1949-09         136
# 9  1949-10         119
#        Month  Passengers
# 134  1960-03         419
# 135  1960-04         461
# 136  1960-05         472
# 137  1960-06         535
# 138  1960-07         622
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432

# %%
# basic dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       144 non-null    object
#  1   Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
# check missing values
df.isnull().sum()
# Out:
# Month         0
# Passengers    0
# dtype: int64

# %%
# plot time series
plt.figure(figsize=(20,5))
plt.plot(df["Month"], df["Passengers"], label="Passengers")
plt.title("Monthly Airline Passengers (1949 to 1960)")
plt.ylabel("Passengers")
plt.xlabel("Month")
plt.xticks(rotation="vertical",fontsize=7)

plt.legend()
plt.show()

# %%
# check for non-stationary (seasonal) data using Augmented Dickey-Fuller test (adfuller)
result = adfuller(df["Passengers"])
p_value = result[1]
adf_value = result[0]
print(f"p-value: {p_value:.3f}")
print(f"ADF Stat: {adf_value:.3f}")
# Out:
# p-value: 0.992
# ADF Stat: 0.815

# %% [markdown]
# Null Hypothesis (H0) -> The data is non-stationary (seasonal)
#
# Alternate Hypothesis (H1) -> The data is stationary (non-seasonal)

# %% [markdown]
# >Inference: The high p-value shows the series is non stationary, so transformations like differencing or decomposition are required before forecasting.

# %%
decompose=seasonal_decompose(
    df["Passengers"],
    model="multiplicative",
    period=12 #12 month

)
decompose.plot()
plt.show()

# %%
train=df.iloc[:-12]
test=df.iloc[-12:]

# %%
test
# Out:
#        Month  Passengers
# 132  1960-01         417
# 133  1960-02         391
# 134  1960-03         419
# 135  1960-04         461
# 136  1960-05         472
# 137  1960-06         535
# 138  1960-07         622
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432

# %%
# train ARIMA model
model = ARIMA(train["Passengers"], order=(5,1,0))
trained_model = model.fit()

# %%
forecast = trained_model.forecast(steps=12)

# %%
# plot forecast vs actual
plt.figure(figsize=(10,5))
plt.plot(train.index, train["Passengers"], label="Train")
plt.plot(test.index, test["Passengers"], label="Test")
plt.plot(test.index, forecast, label="Forecast")
plt.title("ARIMA Forecast on Airline Passengers")
plt.xlabel("Month")
plt.ylabel("Passengers")
plt.legend()
plt.show()

# %%
print(df.dtypes)
# Out:
# Month         object
# Passengers     int64
# dtype: object

# %%
# error metric
mae = mean_absolute_error(test['Passengers'], forecast)
mse = mean_squared_error(test['Passengers'], forecast)
rmse = root_mean_squared_error(test['Passengers'], forecast)

print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
# Out:
# MAE: 67.39
# MSE: 7536.00
# RMSE: 86.81

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
train_log = np.log(train["Passengers"])
test_log = np.log(test["Passengers"])

# %%
sarimax_model = SARIMAX(
    train_log,
    order=(1,1,1),
    seasonal_order=(1,1,1,12)
)

# train the model
trained_sarimax_model = sarimax_model.fit(disp=False, maxiter=200)

# %%
forecast_log = trained_sarimax_model.forecast(steps=12)
forecast_sarimax = np.exp(forecast_log)

# %%
# plot forecast_sarimax vs actual
plt.figure(figsize=(10,5))
plt.plot(train.index, train["Passengers"], label="Train")
plt.plot(test.index, test["Passengers"], label="Test")
plt.plot(test.index, forecast_sarimax, label="Forecast")
plt.title("ARIMA Forecast on Airline Passengers")
plt.xlabel("Month")
plt.ylabel("Passengers")
plt.legend()
plt.show()

# %% [markdown]
# **ARIMA**
#
# Full form: AutoRegressive Integrated Moving Average
#
# One-liner: Predicts future values by removing trend and learning from past values and past errors.
#
# (P, D, Q)
# - P → past values used
# - D → trend removal
# - Q → past errors used
#
# ⸻
#
# **SARIMAX**
#
# Full form: Seasonal AutoRegressive Integrated Moving Average with eXogenous variables
#
# One-liner: ARIMA extended to learn repeating seasonal patterns and optional external inputs.
#
# Seasonal (P, D, Q, S)
# - P, D, Q → seasonal memory and corrections
# - S → season length (12 for monthly data)
#
# ⸻
#
# Quick rule
# - ARIMA → no seasonality
# - SARIMAX → seasonality present
